# %% [markdown]
# <a href="https://colab.research.google.com/github/mushu2843/openCV/blob/Projects/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2 #computer vision
import numpy as np
import matplotlib.pyplot as plt

# advanced image processing for automotive vision

#1. read the input road image
image = cv2.imread("colab.jpg")
if image is None:
  raise FileNotFoundError("colab.jpg not found.Check the image path")

#convert BGR to RGB FOR DISPLAYING with matplotlib
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.axis("off")
plt.show()
